# %% [markdown]
# # Web-Scraping
#
# Sous ce nom se cache une pratique très utile pour toute personne souhaitant travailler sur des informations disponibles en ligne, mais n'existant pas forcément sous la forme d'un tableau Excel... Bref, il s'agit de récupérer des informations depuis Internet.

# %% [markdown]
# Le webscraping est une technique d'extraction du contenu des sites internet, via un programme informatique : nous allons aujourd'hui vous présenter comme créer et exécuter ces robots afin de recupérer rapidement des informations utiles à vos projets actuels ou futurs.

# %% [markdown]
# ## Scrapper avec python
#
# Nous allons essentiellement utiliser le package BeautifulSoup4 pour ce cours, mais d'autres packages existent (Selenium, Scrapy...).
#
# BeautifulSoup sera suffisant quand vous voudrez travailler sur des pages HTML statiques, dès que les informations que vous recherchez sont générées via l'exécution de scripts Javascipt, il vous faudra passer par des outils comme Selenium.
#
# De même, si vous ne connaissez pas l'URL, il faudra passer par un framework comme Scrapy, qui passe facilement d'une page à une autre ("crawl"). Scrapy est plus complexe à manipuler que BeautifulSoup : si vous voulez plus de détails, rendez-vous sur la page du tutorial https://doc.scrapy.org/en/latest/intro/tutorial.html.

# %% [markdown]
# ### Utiliser BeautifulSoup
#
# Les packages pour scrapper des pages HTML :
# - BeautifulSoup (pip3 install bs4)
# - urllib

# %%
import urllib
# !pip install bs4
import bs4
#help(bs4)
# Out:
# Requirement already satisfied: bs4 in /home/kali/anaconda3/lib/python3.9/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /home/kali/anaconda3/lib/python3.9/site-packages (from bs4) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in /home/kali/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->bs4) (2.2.1)

# %% [markdown]
# ### Site
#
# https://www.tradergames.fr/fr/

# %%
# Etape 1 : se connecter à la page et obtenir le code source

url_trader_games = "https://www.tradergames.fr/fr/1091-derniers-arrivages"
    
from urllib import request

request_text = request.urlopen(url_trader_games).read()
print(request_text[:1000])
# Out:
# b'<!doctype html>\n<html lang="fr"  class="default" >\n\n  <head>\n    \n      \n  <meta charset="utf-8">\n\n\n  <meta http-equiv="x-ua-compatible" content="ie=edge">\n\n\n\n  <title>Derniers arrivages</title>\n  <meta name="description" content="">\n  <meta name="keywords" content="">\n        <link rel="canonical" href="https://www.tradergames.fr/fr/1091-derniers-arrivages">\n    \n                  <link rel="alternate" href="https://www.tradergames.fr/fr/1091-derniers-arrivages" hreflang="fr">\n                  <link rel="alternate" href="https://www.tradergames.fr/en/1091-last-arrivals" hreflang="en-us">\n        \n\n\n\n  <meta name="viewport" content="width=device-width, initial-scale=1">\n\n\n\n  <link rel="icon" type="image/vnd.microsoft.icon" href="https://www.tradergames.fr/img/favicon.ico?1622646583">\n  <link rel="shortcut icon" type="image/x-icon" href="https://www.tradergames.fr/img/favicon.ico?1622646583">\n\n\n  \n\n    <link rel="stylesheet" href="https://www.tradergames.fr/themes/at_kinzy/assets/css/t'

# %%
page = bs4.BeautifulSoup(request_text, "lxml")

print(page)
# Out:
# <!DOCTYPE html>
# <html class="default" lang="fr">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <title>Derniers arrivages</title>
# <meta content="" name="description"/>
# <meta content="" name="keywords"/>
# <link href="https://www.tradergames.fr/fr/1091-derniers-arrivages" rel="canonical"/>
# <link href="https://www.tradergames.fr/fr/1091-derniers-arrivages" hreflang="fr" rel="alternate"/>
# <link href="https://www.tradergames.fr/en/1091-last-arrivals" hreflang="en-us" rel="alternate"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://www.tradergames.fr/img/favicon.ico?1622646583" rel="icon" type="image/vnd.microsoft.icon"/>
# <link href="https://www.tradergames.fr/img/favicon.ico?1622646583" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://www.tradergames.fr/themes/at_kinzy/assets/css/theme.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/modules/blockreassurance/views/dist/front.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/modules/ps_facetedsearch/views/dist/front.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/themes/at_kinzy/modules/leobootstrapmenu/views/css/megamenu.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/themes/at_kinzy/modules/leobootstrapmenu/views/css/leomenusidebar.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/themes/at_kinzy/modules/leoslideshow/views/css/typo/typo.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/themes/at_kinzy/modules/leoslideshow/views/css/iView/iview.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/themes/at_kinzy/modules/leoslideshow/views/css/iView/skin_4_responsive/style.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/modules/leofeature/views/css/jquery.mCustomScrollbar.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/themes/at_kinzy/modules/leofeature/views/css/front.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/themes/at_kinzy/modules/leoquicklogin/views/css/front.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/modules/leoquicklogin/views/css/font-awesome.min.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/themes/at_kinzy/modules/leoblog/views/css/leoblog.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/modules/allinone_rewards/css/presta-1.7/allinone_rewards-1.7.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/modules/ets_cookie_banner/views/css/front.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/modules/productlabelsandstickers/views/css/stickers.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/modules/psproductcountdown/views/css/front.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/modules/psproductcountdown/views/css/themes/1-simple.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/js/jquery/ui/themes/base/minified/jquery-ui.min.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/js/jquery/ui/themes/base/minified/jquery.ui.theme.min.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/js/jquery/plugins/fancybox/jquery.fancybox.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/modules/blockgrouptop/views/css/blockgrouptop.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/themes/at_kinzy/modules/leoproductsearch/views/css/leosearch.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/modules/leoproductsearch/views/css/jquery.autocomplete_productsearch.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/themes/at_kinzy/assets/css/custom.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/modules/appagebuilder/views/css/animate.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/themes/at_kinzy/modules/appagebuilder/views/css/owl.carousel.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/themes/at_kinzy/modules/appagebuilder/views/css/owl.theme.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/themes/at_kinzy/modules/appagebuilder/views/css/slick-theme.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/themes/at_kinzy/modules/appagebuilder/views/css/slick.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/themes/at_kinzy/modules/appagebuilder/views/css/ApImageHotspot.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/themes/at_kinzy/modules/appagebuilder/views/css/styles.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/modules/appagebuilder/views/css/unique.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/themes/at_kinzy/modules/appagebuilder/views/css/positions/headerposition3020232379.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/themes/at_kinzy/modules/appagebuilder/views/css/positions/footerposition3207694912.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.tradergames.fr/themes/at_kinzy/modules/appagebuilder/views/css/profiles/profile2859511909.css" media="all" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
#         var LEO_COOKIE_THEME = "AT_KINZY_PANEL_CONFIG";
#         var add_cart_error = "An error occurred while processing your request. Please try again";
#         var ajaxsearch = "1";
#         var buttonwishlist_title_add = "Liste de souhaits";
#         var buttonwishlist_title_remove = "Supprimer du panier";
#         var enable_dropdown_defaultcart = 1;
#         var enable_flycart_effect = 1;
#         var enable_notification = 1;
#         var height_cart_item = "105";
#         var isLogged = false;
#         var leo_push = 0;
#         var leo_search_url = "https:\/\/www.tradergames.fr\/fr\/module\/leoproductsearch\/productsearch";
#         var leo_token = "fb9d660e7d432d629845b69f9afe979f";
#         var leoproductsearch_static_token = "fb9d660e7d432d629845b69f9afe979f";
#         var leoproductsearch_token = "746eae91dc7b36787ea603ec2ea3d202";
#         var lf_is_gen_rtl = false;
#         var lps_show_product_img = "1";
#         var lps_show_product_price = "";
#         var lql_ajax_url = "https:\/\/www.tradergames.fr\/fr\/module\/leoquicklogin\/leocustomer";
#         var lql_is_gen_rtl = false;
#         var lql_module_dir = "\/modules\/leoquicklogin\/";
#         var lql_myaccount_url = "https:\/\/www.tradergames.fr\/fr\/mon-compte";
#         var lql_redirect = "";
#         var number_cartitem_display = 3;
#         var numpro_display = "100";
#         var prestashop = {"cart":{"products":[],"totals":{"total":{"type":"total","label":"Total","amount":0,"value":"0,00\u00a0\u20ac"},"total_including_tax":{"type":"total","label":"Total TTC","amount":0,"value":"0,00\u00a0\u20ac"},"total_excluding_tax":{"type":"total","label":"Total HT :","amount":0,"value":"0,00\u00a0\u20ac"}},"subtotals":{"products":{"type":"products","label":"Sous-total","amount":0,"value":"0,00\u00a0\u20ac"},"discounts":null,"shipping":{"type":"shipping","label":"Livraison","amount":0,"value":""},"tax":null},"products_count":0,"summary_string":"0 articles","vouchers":{"allowed":1,"added":[]},"discounts":[],"minimalPurchase":0,"minimalPurchaseRequired":""},"currency":{"name":"Euro","iso_code":"EUR","iso_code_num":"978","sign":"\u20ac"},"customer":{"lastname":null,"firstname":null,"email":null,"birthday":null,"newsletter":null,"newsletter_date_add":null,"optin":null,"website":null,"company":null,"siret":null,"ape":null,"is_logged":false,"gender":{"type":null,"name":null},"addresses":[]},"language":{"name":"Fran\u00e7ais (French)","iso_code":"fr","locale":"fr-FR","language_code":"fr","is_rtl":"0","date_format_lite":"d\/m\/Y","date_format_full":"d\/m\/Y H:i:s","id":1},"page":{"title":"","canonical":"https:\/\/www.tradergames.fr\/fr\/1091-derniers-arrivages","meta":{"title":"Derniers arrivages","description":"","keywords":"","robots":"index"},"page_name":"category","body_classes":{"lang-fr":true,"lang-rtl":false,"country-FR":true,"currency-EUR":true,"layout-left-column":true,"page-category":true,"tax-display-enabled":true,"category-id-1091":true,"category-Derniers arrivages":true,"category-id-parent-2":true,"category-depth-level-2":true},"admin_notifications":[]},"shop":{"name":"Trader Games","logo":"https:\/\/www.tradergames.fr\/img\/prestashop-logo-1620838179.jpg","stores_icon":"https:\/\/www.tradergames.fr\/img\/logo_stores.png","favicon":"https:\/\/www.tradergames.fr\/img\/favicon.ico"},"urls":{"base_url":"https:\/\/www.tradergames.fr\/","current_url":"https:\/\/www.tradergames.fr\/fr\/1091-derniers-arrivages","shop_domain_url":"https:\/\/www.tradergames.fr","img_ps_url":"https:\/\/www.tradergames.fr\/img\/","img_cat_url":"https:\/\/www.tradergames.fr\/img\/c\/","img_lang_url":"https:\/\/www.tradergames.fr\/img\/l\/","img_prod_url":"https:\/\/www.tradergames.fr\/img\/p\/","img_manu_url":"https:\/\/www.tradergames.fr\/img\/m\/","img_sup_url":"https:\/\/www.tradergames.fr\/img\/su\/","img_ship_url":"https:\/\/www.tradergames.fr\/img\/s\/","img_store_url":"https:\/\/www.tradergames.fr\/img\/st\/","img_col_url":"https:\/\/www.tradergames.fr\/img\/co\/","img_url":"https:\/\/www.tradergames.fr\/themes\/at_kinzy\/assets\/img\/","css_url":"https:\/\/www.tradergames.fr\/themes\/at_kinzy\/assets\/css\/","js_url":"https:\/\/www.tradergames.fr\/themes\/at_kinzy\/assets\/js\/","pic_url":"https:\/\/www.tradergames.fr\/upload\/","pages":{"address":"https:\/\/www.tradergames.fr\/fr\/adresse","addresses":"https:\/\/www.tradergames.fr\/fr\/adresses","authentication":"https:\/\/www.tradergames.fr\/fr\/connexion","cart":"https:\/\/www.tradergames.fr\/fr\/panier","category":"https:\/\/www.tradergames.fr\/fr\/index.php?controller=category","cms":"https:\/\/www.tradergames.fr\/fr\/index.php?controller=cms","contact":"https:\/\/www.tradergames.fr\/fr\/nous-contacter","discount":"https:\/\/www.tradergames.fr\/fr\/reduction","guest_tracking":"https:\/\/www.tradergames.fr\/fr\/suivi-commande-invite","history":"https:\/\/www.tradergames.fr\/fr\/historique-commandes","identity":"https:\/\/www.tradergames.fr\/fr\/identite","index":"https:\/\/www.tradergames.fr\/fr\/","my_account":"https:\/\/www.tradergames.fr\/fr\/mon-compte","order_confirmation":"https:\/\/www.tradergames.fr\/fr\/confirmation-commande","order_detail":"https:\/\/www.tradergames.fr\/fr\/index.php?controller=order-detail","order_follow":"https:\/\/www.tradergames.fr\/fr\/suivi-commande","order":"https:\/\/www.tradergames.fr\/fr\/commande","order_return":"https:\/\/www. ...
#         var psemailsubscription_subscription = "https:\/\/www.tradergames.fr\/fr\/module\/ps_emailsubscription\/subscription";
#         var psr_icon_color = "#F19D76";
#         var show_popup = 1;
#         var text_no_product = "Aucun produit trouv\u00e9";
#         var type_dropdown_defaultcart = "slidebar_right";
#         var type_flycart_effect = "fade";
#         var url_leoproductattribute = "https:\/\/www.tradergames.fr\/fr\/module\/leofeature\/LeoProductAttribute";
#         var width_cart_item = "300";
#         var wishlist_add = "Le produit a \u00e9t\u00e9 ajout\u00e9 \u00e0 votre liste";
#         var wishlist_cancel_txt = "Annuler";
#         var wishlist_confirm_del_txt = "Supprimer l'\u00e9l\u00e9ment s\u00e9lectionn\u00e9?";
#         var wishlist_del_default_txt = "Impossible de supprimer par d\u00e9faut liste";
#         var wishlist_email_txt = "Email";
#         var wishlist_loggin_required = "Vous devez \u00eatre connect\u00e9 pour g\u00e9rer votre liste";
#         var wishlist_ok_txt = "D'accord";
#         var wishlist_quantity_required = "Vous devez saisir une quantit\u00e9";
#         var wishlist_remove = "Le produit a \u00e9t\u00e9 retir\u00e9 de votre liste";
#         var wishlist_reset_txt = "R\u00e9initialiser";
#         var wishlist_send_txt = "Envoyer";
#         var wishlist_send_wishlist_txt = "Envoyer liste";
#         var wishlist_url = "https:\/\/www.tradergames.fr\/fr\/module\/leofeature\/mywishlist";
#         var wishlist_viewwishlist = "Voir votre liste";
#       </script>
# <script type="text/javascript">
# 	var choosefile_text = "Choisir un fichier";
# 	var turnoff_popup_text = "Ne pas afficher ce popup à nouveau";
#
# 	var size_item_quickview = 144;
# 	var style_scroll_quickview = 'horizontal';
#
# 	var size_item_page = 144;
# 	var style_scroll_page = 'horizontal';
#
# 	var size_item_quickview_attr = 144;
# 	var style_scroll_quickview_attr = 'horizontal';
#
# 	var size_item_popup = 190;
# 	var style_scroll_popup = 'vertical';
# </script>
# <!-- emarketing start -->
# <!-- emarketing end --><script type="text/javascript">
#
# 	var FancyboxI18nClose = "Fermer";
# 	var FancyboxI18nNext = "Prochain";
# 	var FancyboxI18nPrev = "précédent";
# 	var current_link = "http://www.tradergames.fr/fr/";
# 	var currentURL = window.location;
# 	currentURL = String(currentURL);
# 	currentURL = currentURL.replace("https://","").replace("http://","").replace("www.","").replace( /#\w*/, "" );
# 	current_link = current_link.replace("https://","").replace("http://","").replace("www.","");
# 	var text_warning_select_txt = "S'il vous plaît sélectionner un pour supprimer?";
# 	var text_confirm_remove_txt = "Etes-vous sûr de retirer de pied de page?";
# 	var close_bt_txt = "Fermer";
# 	var list_menu = [];
# 	var list_menu_tmp = {};
# 	var list_tab = [];
# 	var isHomeMenu = 0;
#
# </script><!-- @file modules\appagebuilder\views\templates\hook\header -->
# <script>
# 	/**
# 	 * List functions will run when document.ready()
# 	 */
# 	var ap_list_functions = [];
# 	/**
# 	 * List functions will run when window.load()
# 	 */
# 	var ap_list_functions_loaded = [];
#
# 	/**
# 	 * List functions will run when document.ready() for theme
# 	 */
#
# 	var products_list_functions = [];
# </script>
# <script type="text/javascript">
# 	var leoOption = {
# 		category_qty:1,
# 		product_list_image:1,
# 		product_one_img:1,
# 		productCdown: 1,
# 		productColor: 0,
# 		homeWidth: 1000,
# 		homeheight: 1000,
# 	}
#
# 	ap_list_functions.push(function(){
# 		if (typeof $.LeoCustomAjax !== "undefined" && $.isFunction($.LeoCustomAjax)) {
# 			var leoCustomAjax = new $.LeoCustomAjax();
# 			leoCustomAjax.processAjax();
# 		}
# 	});
# </script>
# <script type="text/javascript">
# 	(window.gaDevIds=window.gaDevIds||[]).push('d6YPbH');
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#             ga('create', 'UA-84393122-1', 'auto');
#                         ga('send', 'pageview');
#
#     ga('require', 'ec');
# </script>
# <style type="text/css">
#             #product .pspc-wrp.pspc_displayProductPriceBlock {
#         display: block !important;
#     }
#     .ajax_block_product .pspc-wrp.pspc_displayProductPriceBlock,
#     .product_list .pspc-wrp.pspc_displayProductPriceBlock,
#     #product_list .pspc-wrp.pspc_displayProductPriceBlock,
#     .product-miniature .pspc-wrp.pspc_displayProductPriceBlock {
#         display: none !important;
#     }
#
#     </style>
# <script type="text/javascript">
#     var pspc_labels = ['days', 'hours', 'minutes', 'seconds'];
#     var pspc_labels_lang = {
#         'days': 'jrs.',
#         'hours': 'h.',
#         'minutes': 'min.',
#         'seconds': 'sec.'
#     };
#     var pspc_labels_lang_1 = {
#         'days': 'jrs.',
#         'hours': 'h.',
#         'minutes': 'min.',
#         'seconds': 'sec.'
#     };
#     var pspc_offer_txt = "Disponible dans :";
#     var pspc_theme = "1-simple";
#     var pspc_psv = 1.7;
#     var pspc_hide_after_end = 1;
#     var pspc_hide_expired = 1;
#     var pspc_highlight = "seconds";
#     var pspc_position_product = "displayProductPriceBlock";
#     var pspc_position_list = "displayProductListReviews";
#     var pspc_adjust_positions = 1;
#     var pspc_token = "fb9d660e7d432d629845b69f9afe979f";
# </script>
# </head>
# <body class="lang-fr country-fr currency-eur layout-left-column page-category tax-display-enabled category-id-1091 category-derniers-arrivages category-id-parent-2 category-depth-level-2 fullwidth" id="category">
# <script>
#         window.fbAsyncInit = function() {
#             FB.init({
#                 appId      : '441506616218023',
#                 cookie     : true,  // enable cookies to allow the server to access
#                 xfbml      : true,  // parse social plugins on this page
#                 version    : 'v2.9', // use graph api version 2.8
#                 scope: 'email, user_birthday',
#             });
#         };
#
#         // Load the SDK asynchronously
#         (function(d, s, id) {
#             var js, fjs = d.getElementsByTagName(s)[0];
#             if (d.getElementById(id)) return;
#             js = d.createElement(s); js.id = id;
#             js.src = "//connect.facebook.net/fr_FR/sdk.js";
#             fjs.parentNode.insertBefore(js, fjs);
#         }(document, 'script', 'facebook-jssdk'));
#     </script>
# <script>
# var google_client_id= "1038085221664-a11l6ld3cq8b3qcbejud1bsp8gsf5m0j.apps.googleusercontent.com";
#
# </script>
# <script src="https://apis.google.com/js/api:client.js"></script>
# <main id="page">
# <header id="header">
# <div class="header-container">
# <div class="header-banner">
# <div class="container">
# <div class="inner"></div>
# </div>
# </div>
# <nav class="header-nav">
# <div class="topnav">
# <div class="inner"></div>
# </div>
# <div class="bottomnav">
# <div class="inner"><!-- @file modules\appagebuilder\views\templates\hook\ApRow -->
# <div class="wrapper" style="background:#033a7d">
# <div class="container-medium">
# <div class="row ApRow has-bg bg-fullwidth-container" style="">
# <!-- @file modules\appagebuilder\views\templates\hook\ApColumn -->
# <div class="col-xl-9-6 col-lg-6 col-md-6 col-sm-12 col-xs-12 col-sp-12 header-nav-flex ApColumn">
# <!-- @file modules\appagebuilder\views\templates\hook\ApModule -->
# <div class="language-selector-wrapper dropdown js-dropdown popup-over" id="language-selector-label">
# <a aria-label="Sélecteur de langue" class="popup-title" data-toggle="dropdown" href="javascript:void(0)" title="Langue">
# <span class="hidden-xl-down">Langue:</span>
# <span class="iso_code">
#                         fr
#                                 </span>
# <i class="fa fa-angle-down"></i>
# </a>
# <ul aria-labelledby="language-selector-label" class="dropdown-menu popup-content link language-selector">
# <li class="current">
# <a class="dropdown-item" data-iso-code="fr" href="https://www.tradergames.fr/fr/1091-derniers-arrivages">
# <img alt="fr" height="11" src="https://www.tradergames.fr/img/l/1.jpg" width="16"/>
# <span>Français</span>
# </a>
# </li>
# <li>
# <a class="dropdown-item" data-iso-code="en" href="https://www.tradergames.fr/en/1091-last-arrivals">
# <img alt="en" height="11" src="https://www.tradergames.fr/img/l/2.jpg" width="16"/>
# <span>English</span>
# </a>
# </li>
# </ul>
# </div>
# <!-- @file modules\appagebuilder\views\templates\hook\ApModule -->
# <div class="userinfo-selector popup-over pull-right e-scale">
# <ul class="nav_title_info">
# <li>
# <a class="signin leo-quicklogin" data-enable-sociallogin="enable" data-layout="login" data-type="popup" href="javascript:void(0)" rel="nofollow" title="Identifiez-vous">
# <span>Connexion</span>
# </a>
# </li>
# <li>
# <a class="register leo-quicklogin" data-enable-sociallogin="enable" data-layout="register" data-type="popup" href="javascript:void(0)" rel="nofollow" title="S'inscrire">
# <span>S'inscrire</span>
# </a>
# </li>
# </ul>
# <div class="hidden-xs-up">
# <a class="popup-title" data-toggle="dropdown" href="javascript:void(0)" title="Compte">
# <i class="nova-user"></i>
# <span class="user_title">Mon compte</span>
# <i class="fa fa-angle-down"></i>
# </a>
# <ul class="popup-content dropdown-menu user-info">
# <li>
# <a class="signin leo-quicklogin" data-enable-sociallogin="enable" data-layout="login" data-type="popup" href="javascript:void(0)" rel="nofollow" title="Identifiez-vous">
# <i class="fa fa-unlock-alt"></i>
# <span>Connexion</span>
# </a>
# </li>
# <li>
# <a class="myacount dropdown-item" href="https://www.tradergames.fr/fr/mon-compte" rel="nofollow" title="Mon compte">
# <i class="fa fa-user"></i>
# <span>Mon compte</span>
# </a>
# </li>
# <!--li>
#         <a
#           class="checkout dropdown-item"
#           href="//www.tradergames.fr/fr/panier?action=show"
#           title="Caisse"
#           rel="nofollow"
#         >
#         <i class="fa fa-sign-out" aria-hidden="true"></i>
#           <span>Commander</span>
#         </a>
#       </li-->
# <li>
# <a class="ap-btn-wishlist dropdown-item" href="//www.tradergames.fr/fr/module/leofeature/mywishlist" rel="nofollow" title="Favoris">
# <i class="fa fa-heart-o"></i>
# <span>Favoris</span>
# <span class="ap-total-wishlist ap-total"></span>
# </a> </li>
# </ul>
# </div>
# </div>
# </div> </div>
# </div>
# </div>
# <script>
# 		ap_list_functions.push(function(){
# 			$.stellar({horizontalScrolling:false});
# 		});
# 	</script>
# </div>
# </div>
# </nav>
# <div class="header-top">
# <div class="inner"><!-- @file modules\appagebuilder\views\templates\hook\ApRow -->
# <div class="wrapper">
# <div class="container-medium">
# <div class="row header-flex ApRow has-bg bg-boxed" data-bg_data=" no-repeat" style="background: no-repeat;">
# <!-- @file modules\appagebuilder\views\templates\hook\ApColumn -->
# <div class="col-xl-3 col-lg-3 col-md-3 col-sm-3 col-xs-3 col-sp-5 left-header ApColumn">
# <!-- @file modules\appagebuilder\views\templates\hook\ApGenCode -->
# <a href="https://www.tradergames.fr/"> <img alt="Trader Games" class="logo img-fluid" src="https://www.tradergames.fr/img/prestashop-logo-1620838179.jpg"/></a>
# </div><!-- @file modules\appagebuilder\views\templates\hook\ApColumn -->
# <div class="col-xl-6 col-lg-6 col-md-6 col-sm-5 col-xs-7 col-sp-5 center-header ApColumn">
# <!-- @file modules\appagebuilder\views\templates\hook\ApModule -->
# <div class="search-widget block exclusive" id="leo_search_block_top">
# <a class="float-xs-right popup-title" data-toggle="dropdown" href="javascript:void(0)" id="click_show_search">
# <i class="nova-search"></i>
# </a>
# <form action="https://www.tradergames.fr/fr/index.php?controller=productsearch" data-in-category="dans la catégorie" data-label-products="Products" data-label-suggestion="Suggestion" data-products-for="Produit pour" data-search-for="Rechercher" data-view-all="Voir tout" id="leosearchtopbox" method="get">
# <input name="fc" type="hidden" value="module"/>
# <input name="module" type="hidden" value="leoproductsearch"/>
# <input name="controller" type="hidden" value="productsearch"/>
# <input name="txt_not_found" type="hidden" value="Aucun produits trouvé"/>
# <input name="leoproductsearch_static_token" type="hidden" value="fb9d660e7d432d629845b69f9afe979f"/>
# <div class="block_content clearfix leoproductsearch-content">
# <div class="leoproductsearch-result">
# <div class="leoproductsearch-loading cssload-container">
# <div class="cssload-speeding-wheel"></div>
# </div>
# <input class="search_query form-control grey" id="leo_search_query_top" name="search_query" placeholder="Rechercher" type="text" value=""/>
# <button class="btn btn-default button button-small" id="leo_search_top_button" type="submit"><i class="nova-search"></i></button>
# <div class="ac_results lps_results"></div>
# </div>
# </div>
# </form>
# </div>
# <script type="text/javascript">
# 		var blocksearch_type = 'top';
# 	</script>
# </div><!-- @file modules\appagebuilder\views\templates\hook\ApColumn -->
# <div class="col-xl-3 col-lg-3 col-md-5 col-sm-4 col-xs-2 col-sp-2 right-header ApColumn">
# <!-- @file modules\appagebuilder\views\templates\hook\ApModule -->
# <div id="cart-block">
# <div class="blockcart cart-preview inactive" data-refresh-url="//www.tradergames.fr/fr/module/ps_shoppingcart/ajax">
# <div class="header">
# <i class="nova-shopping-cart"></i>
# <div class="cart-quantity">
# <span class="title_cart">Mon panier</span>
# <span class="cart-products-count">0 <span class="cart-unit"> articles</span></span>
# </div>
# <div class="mini_card">
# <span>Votre panier est actuellement vide.</span>
# </div>
# </div>
# </div>
# </div>
# </div> </div>
# </div>
# </div>
# <!-- @file modules\appagebuilder\views\templates\hook\ApRow -->
# <div class="wrapper" style="background:#033a7d">
# <div class="container-medium">
# <div class="row box-header ApRow has-bg bg-fullwidth-container" style="">
# <!-- @file modules\appagebuilder\views\templates\hook\ApColumn -->
# <div class="col-xl-12 col-lg-9-6 col-md-7 col-sm-6 col-xs-3 col-sp-3 header-menu ApColumn">
# <!-- @file modules\appagebuilder\views\templates\hook\ApSlideShow -->
# <div class="ApMegamenu" id="memgamenu-form_3225252796">
# <nav class="leo-megamenu cavas_menu navbar navbar-default enable-canvas" data-megamenu-id="3225252796" role="navigation">
# <!-- Brand and toggle get grouped for better mobile display -->
# <div class="navbar-header">
# <button class="navbar-toggler hidden-lg-up" data-target=".megamenu-off-canvas-3225252796" data-toggle="collapse" type="button">
# <span class="sr-only">Basculer la navigation</span>
#                                             ☰
#                                             <!--
#                                             <span class="icon-bar"></span>
#                                             <span class="icon-bar"></span>
#                                             <span class="icon-bar"></span>
#                                             -->
# </button>
# </div>
# <!-- Collect the nav links, forms, and other content for toggling -->
# <div class="leo-top-menu collapse navbar-toggleable-md megamenu-off-canvas megamenu-off-canvas-3225252796"><ul class="nav navbar-nav megamenu horizontal"><li class="nav-item parent dropdown aligned-left" data-menu-type="category">
# <a class="nav-link dropdown-toggle has-category" data-toggle="dropdown" href="https://www.tradergames.fr/fr/147-retrogaming" target="_self">
# <span class="menu-title">Rétrogaming</span>
# </a>
# <b class="caret"></b>
# <div class="dropdown-sub dropdown-menu" style="width:750px">
# <div class="dropdown-menu-inner">
# <div class="row">
# <div class="mega-col col-md-3">
# <div class="mega-col-inner">
# <div class="leo-widget" data-id_widget="1620839438">
# <div class="widget-subcategories">
# <div class="widget-inner">
# <div class="menu-title">
# <a class="img" href="https://www.tradergames.fr/fr/252-sony" title="Sony">
#                             Sony
#                     </a>
# </div>
# <ul>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/310-playstation-3" title="Playstation 3">
#                                 Playstation 3
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/311-playstation-2" title="Playstation 2">
#                                 Playstation 2
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/312-playstation-1" title="Playstation 1">
#                                 Playstation 1
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/313-playstation-portable" title="Playstation Portable">
#                                 Playstation Portable
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/169-playstation-vita" title="Playstation Vita">
#                                 Playstation Vita
#                         </a>
# </li>
# </ul>
# </div>
# </div>
# </div><div class="leo-widget" data-id_widget="1620993939">
# <div class="widget-subcategories">
# <div class="widget-inner">
# <div class="menu-title">
# <a class="img" href="https://www.tradergames.fr/fr/261-xbox-360" title="Xbox / 360">
#                             Xbox / 360
#                     </a>
# </div>
# <ul>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/684-xbox" title="Xbox">
#                                 Xbox
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/685-xbox-360" title="Xbox 360">
#                                 Xbox 360
#                         </a>
# </li>
# </ul>
# </div>
# </div>
# </div><div class="leo-widget" data-id_widget="1621957986">
# <div class="widget-subcategories">
# <div class="widget-inner">
# <div class="menu-title">
# <a class="img" href="https://www.tradergames.fr/fr/1128-nec" title="Nec">
#                             Nec
#                     </a>
# </div>
# <ul>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/253-nec" title="Nec">
#                                 Nec
#                         </a>
# </li>
# </ul>
# </div>
# </div>
# </div><div class="leo-widget" data-id_widget="1620994393">
# <div class="widget-subcategories">
# <div class="widget-inner">
# <div class="menu-title">
# <a class="img" href="https://www.tradergames.fr/fr/263-pc" title="Pc">
#                             Pc
#                     </a>
# </div>
# <ul>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/931-jeux-pc" title="Jeux PC">
#                                 Jeux PC
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/791-collectors" title="Collectors">
#                                 Collectors
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/268-accessoires" title="Accessoires">
#                                 Accessoires
#                         </a>
# </li>
# </ul>
# </div>
# </div>
# </div><div class="leo-widget" data-id_widget="1647012301">
# <div class="widget-subcategories">
# <div class="widget-inner">
# <div class="menu-title">
# <a class="img" href="https://www.tradergames.fr/fr/1140-protection" title="Protection">
#                             Protection
#                     </a>
# </div>
# <ul>
# </ul>
# </div>
# </div>
# </div> </div>
# </div>
# <div class="mega-col col-md-3">
# <div class="mega-col-inner">
# <div class="leo-widget" data-id_widget="1620993602">
# <div class="widget-subcategories">
# <div class="widget-inner">
# <div class="menu-title">
# <a class="img" href="https://www.tradergames.fr/fr/250-nintendo" title="Nintendo">
#                             Nintendo
#                     </a>
# </div>
# <ul>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/371-nintendo-nes" title="Nintendo / Nes">
#                                 Nintendo / Nes
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/372-famicom" title="Famicom">
#                                 Famicom
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/373-super-nintendo" title="Super nintendo">
#                                 Super nintendo
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/375-super-famicom" title="Super famicom">
#                                 Super famicom
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/376-nintendo-64" title="Nintendo 64">
#                                 Nintendo 64
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/377-gamecube" title="Gamecube">
#                                 Gamecube
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/378-nintendo-wii" title="Nintendo wii">
#                                 Nintendo wii
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/171-nintendo-wii-u" title="Nintendo Wii U">
#                                 Nintendo Wii U
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/799-virtual-boy" title="Virtual boy">
#                                 Virtual boy
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/418-game-boy" title="Game boy">
#                                 Game boy
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/419-game-boy-color" title="Game boy color">
#                                 Game boy color
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/420-game-boy-advance" title="Game boy advance">
#                                 Game boy advance
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/421-game-boy-micro" title="Game boy micro">
#                                 Game boy micro
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/380-nintendo-ds" title="Nintendo DS">
#                                 Nintendo DS
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/170-nintendo-3ds" title="Nintendo 3DS">
#                                 Nintendo 3DS
#                         </a>
# </li>
# </ul>
# </div>
# </div>
# </div> </div>
# </div>
# <div class="mega-col col-md-3">
# <div class="mega-col-inner">
# <div class="leo-widget" data-id_widget="1620993647">
# <div class="widget-subcategories">
# <div class="widget-inner">
# <div class="menu-title">
# <a class="img" href="https://www.tradergames.fr/fr/251-sega" title="Sega">
#                             Sega
#                     </a>
# </div>
# <ul>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/335-megadrive" title="Megadrive">
#                                 Megadrive
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/338-game-gear" title="Game gear">
#                                 Game gear
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/339-saturn" title="Saturn">
#                                 Saturn
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/340-dreamcast" title="Dreamcast">
#                                 Dreamcast
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/334-master-system" title="Master system">
#                                 Master system
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/1049-mark-iii" title="Mark III">
#                                 Mark III
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/1050-sg-1000" title="SG-1000">
#                                 SG-1000
#                         </a>
# </li>
# </ul>
# </div>
# </div>
# </div><div class="leo-widget" data-id_widget="1620994009">
# <div class="widget-subcategories">
# <div class="widget-inner">
# <div class="menu-title">
# <a class="img" href="https://www.tradergames.fr/fr/255-bandai" title="Bandai">
#                             Bandai
#                     </a>
# </div>
# <ul>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/293-wonderswan" title="Wonderswan">
#                                 Wonderswan
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/294-playdia" title="Playdia">
#                                 Playdia
#                         </a>
# </li>
# </ul>
# </div>
# </div>
# </div><div class="leo-widget" data-id_widget="1620994083">
# <div class="widget-subcategories">
# <div class="widget-inner">
# <div class="menu-title">
# <a class="img" href="https://www.tradergames.fr/fr/259-atari" title="Atari">
#                             Atari
#                     </a>
# </div>
# <ul>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/1058-jaguar" title="Jaguar">
#                                 Jaguar
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/1059-lynx" title="Lynx">
#                                 Lynx
#                         </a>
# </li>
# </ul>
# </div>
# </div>
# </div> </div>
# </div>
# <div class="mega-col col-md-3">
# <div class="mega-col-inner">
# <div class="leo-widget" data-id_widget="1620993765">
# <div class="widget-subcategories">
# <div class="widget-inner">
# <div class="menu-title">
# <a class="img" href="https://www.tradergames.fr/fr/254-snk" title="Snk">
#                             Snk
#                     </a>
# </div>
# <ul>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/277-neogeo-aes" title="Neogeo AES">
#                                 Neogeo AES
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/278-neogeo-cd" title="Neogeo CD">
#                                 Neogeo CD
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/279-neogeo-pocket" title="Neogeo pocket">
#                                 Neogeo pocket
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/280-neogeo-mvs" title="Neogeo MVS">
#                                 Neogeo MVS
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/933-neogeo-books" title="Neogeo Books">
#                                 Neogeo Books
#                         </a>
# </li>
# </ul>
# </div>
# </div>
# </div><div class="leo-widget" data-id_widget="1620994032">
# <div class="widget-subcategories">
# <div class="widget-inner">
# <div class="menu-title">
# <a class="img" href="https://www.tradergames.fr/fr/256-3do" title="3do">
#                             3do
#                     </a>
# </div>
# <ul>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/302-consoles" title="Consoles">
#                                 Consoles
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/303-jeux-d-occasion" title="Jeux d'occasion">
#                                 Jeux d'occasion
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/304-jeux-neufs" title="Jeux neufs">
#                                 Jeux neufs
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/683-accessoires-" title="Accessoires">
#                                 Accessoires
#                         </a>
# </li>
# </ul>
# </div>
# </div>
# </div><div class="leo-widget" data-id_widget="1620994066">
# <div class="widget-subcategories">
# <div class="widget-inner">
# <div class="menu-title">
# <a class="img" href="https://www.tradergames.fr/fr/258-msx" title="Msx">
#                             Msx
#                     </a>
# </div>
# <ul>
# </ul>
# </div>
# </div>
# </div><div class="leo-widget" data-id_widget="1620994102">
# <div class="widget-subcategories">
# <div class="widget-inner">
# <div class="menu-title">
# <a class="img" href="https://www.tradergames.fr/fr/260-amiga" title="Amiga">
#                             Amiga
#                     </a>
# </div>
# <ul>
# </ul>
# </div>
# </div>
# </div><div class="leo-widget" data-id_widget="1620994050">
# <div class="widget-subcategories">
# <div class="widget-inner">
# <div class="menu-title">
# <a class="img" href="https://www.tradergames.fr/fr/257-epoch" title="Epoch">
#                             Epoch
#                     </a>
# </div>
# <ul>
# </ul>
# </div>
# </div>
# </div><div class="leo-widget" data-id_widget="1620994173">
# <div class="widget-subcategories">
# <div class="widget-inner">
# <div class="menu-title">
# <a class="img" href="https://www.tradergames.fr/fr/838-consoles-d-emulation" title="Consoles d'émulation">
#                             Consoles d'émulation
#                     </a>
# </div>
# <ul>
# </ul>
# </div>
# </div>
# </div><div class="leo-widget" data-id_widget="1620994236">
# <div class="widget-subcategories">
# <div class="widget-inner">
# <div class="menu-title">
# <a class="img" href="https://www.tradergames.fr/fr/150-gamewatch-lsi-lcd" title="Game&amp;Watch , lsi , lcd">
#                             Game&amp;Watch , lsi , lcd
#                     </a>
# </div>
# <ul>
# </ul>
# </div>
# </div>
# </div><div class="leo-widget" data-id_widget="1632494134">
# <div class="widget-subcategories">
# <div class="widget-inner">
# <div class="menu-title">
# <a class="img" href="https://www.tradergames.fr/fr/1127-vectrex" title="Vectrex">
#                             Vectrex
#                     </a>
# </div>
# <ul>
# </ul>
# </div>
# </div>
# </div> </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="nav-item parent dropdown aligned-left" data-menu-type="category">
# <a class="nav-link dropdown-toggle has-category" data-toggle="dropdown" href="https://www.tradergames.fr/fr/146-next-gen" target="_self">
# <span class="menu-title">PS5 - PS4</span>
# </a>
# <b class="caret"></b>
# <div class="dropdown-sub dropdown-menu" style="width:480px">
# <div class="dropdown-menu-inner">
# <div class="row">
# <div class="mega-col col-md-6">
# <div class="mega-col-inner">
# <div class="leo-widget" data-id_widget="1620987968">
# <div class="widget-subcategories">
# <div class="widget-inner">
# <div class="menu-title">
# <a class="img" href="https://www.tradergames.fr/fr/973-playstation-5" title="Playstation 5">
#                             Playstation 5
#                     </a>
# </div>
# <ul>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/974-tous-les-jeux-Playstation-5" title="Tous les jeux">
#                                 Tous les jeux
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/975-jeux-neufs-Playstation-5" title="Jeux neufs">
#                                 Jeux neufs
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/976-jeux-d-occasion-Playstation-5" title="Jeux d'occasion">
#                                 Jeux d'occasion
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/978-jeux-import-japon-us-asie" title="Jeux import (Japon, US, Asie)">
#                                 Jeux import (Japon, US, Asie)
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/984-Jeux-editions-limitees-Playstation-5" title="Editions limitées">
#                                 Editions limitées
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/985-precommandes-Playstation-5" title="Précommandes">
#                                 Précommandes
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/987-Consoles-Playstation-5" title="Consoles">
#                                 Consoles
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/986-Accessoires-Playstation-5" title="Accessoires">
#                                 Accessoires
#                         </a>
# </li>
# </ul>
# </div>
# </div>
# </div> </div>
# </div>
# <div class="mega-col col-md-6">
# <div class="mega-col-inner">
# <div class="leo-widget" data-id_widget="1620988019">
# <div class="widget-subcategories">
# <div class="widget-inner">
# <div class="menu-title">
# <a class="img" href="https://www.tradergames.fr/fr/152-playstation-4" title="Playstation 4">
#                             Playstation 4
#                     </a>
# </div>
# <ul>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/897-tous-les-jeux-" title="Tous les jeux">
#                                 Tous les jeux
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/898-jeux-neufs" title="Jeux neufs">
#                                 Jeux neufs
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/899-jeux-d-occasion-" title="Jeux d'occasion">
#                                 Jeux d'occasion
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/902-jeux-import-japon-us-asie" title="Jeux import (Japon, US, Asie)">
#                                 Jeux import (Japon, US, Asie)
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/185-editions-limitees" title="Editions limitées">
#                                 Editions limitées
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/159-precommandes-" title="Précommandes">
#                                 Précommandes
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/153-consoles-" title="Consoles">
#                                 Consoles
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/158-accessoires-" title="Accessoires">
#                                 Accessoires
#                         </a>
# </li>
# </ul>
# </div>
# </div>
# </div> </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="nav-item parent dropdown aligned-left" data-menu-type="category">
# <a class="nav-link dropdown-toggle has-category" data-toggle="dropdown" href="https://www.tradergames.fr/fr/855-nintendo-switch" target="_self">
# <span class="menu-title">Switch</span>
# </a>
# <b class="caret"></b>
# <div class="dropdown-sub dropdown-menu" style="width:400px">
# <div class="dropdown-menu-inner">
# <div class="row">
# <div class="mega-col col-md-7">
# <div class="mega-col-inner">
# <div class="leo-widget" data-id_widget="1620990553">
# <div class="widget-subcategories">
# <div class="widget-inner">
# <div class="menu-title">
# <a class="img" href="https://www.tradergames.fr/fr/855-nintendo-switch" title="Nintendo Switch">
#                             Nintendo Switch
#                     </a>
# </div>
# <ul>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/913-tous-les-jeux-" title="Tous les jeux">
#                                 Tous les jeux
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/915-jeux-neufs" title="Jeux neufs">
#                                 Jeux neufs
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/916-jeux-d-occasion-" title="Jeux d'occasion">
#                                 Jeux d'occasion
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/914-jeux-import-japon-us-asie" title="Jeux import (Japon, US, Asie)">
#                                 Jeux import (Japon, US, Asie)
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/860-editions-limitees" title="Editions limitées">
#                                 Editions limitées
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/861-precommandes" title="Précommandes">
#                                 Précommandes
#                         </a>
# </li>
# <li class="clearfix">
# <a class="img" href="https://www.tradergames.fr/fr/856-consoles-" title="Consoles">
#                                 Consoles
#                         </a>
# </li>
# <li class="clearfix">
# ...
#
# 	var size_item_quickview = 144;
# 	var style_scroll_quickview = 'horizontal';
#
# 	var size_item_page = 144;
# 	var style_scroll_page = 'horizontal';
#
# 	var size_item_quickview_attr = 144;
# 	var style_scroll_quickview_attr = 'horizontal';
#
# 	var size_item_popup = 190;
# 	var style_scroll_popup = 'vertical';
# </script>
# <div class="leo-fly-cart-mask"></div>
# <div class="leo-fly-cart-slidebar slidebar_right">
# <div class="leo-fly-cart disable-dropdown">
# <div class="leo-fly-cart-wrapper">
# <div class="leo-fly-cart-icon-wrapper">
# <i class="material-icons">close</i>
# <span class="cart-title">Panier</span>
# </div>
# <div class="dd-fly-cart-cssload-loader"></div>
# </div>
# </div>
# </div><div class="leo-fly-cart solo type-fixed enable-slidebar" data-type="slidebar_bottom" style="position: fixed; bottom:30px; left:10px">
# <div class="leo-fly-cart-icon-wrapper">
# <a class="leo-fly-cart-icon" data-type="slidebar_bottom" href="javascript:void(0)"><i class="material-icons"></i></a>
# <span class="leo-fly-cart-total"></span>
# </div>
# <div class="leo-fly-cart-cssload-loader"></div>
# </div> <div class="leo-fly-cart-mask"></div>
# <div class="leo-fly-cart-slidebar slidebar_bottom">
# <div class="leo-fly-cart disable-dropdown">
# <div class="leo-fly-cart-wrapper">
# <div class="leo-fly-cart-icon-wrapper">
# <i class="material-icons">close</i>
# <span class="cart-title">Panier</span>
# </div>
# <div class="dd-fly-cart-cssload-loader"></div>
# </div>
# </div>
# </div><div aria-hidden="true" class="modal leo-quicklogin-modal fade" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-body">
# <div class="leo-quicklogin-form row">
# <div class="leo-form leo-login-form col-sm-6 leo-form-active">
# <h3 class="leo-login-title">
# <span class="title-both">
# 				Compté déjà existant
# 			</span>
# <span class="title-only">
# 				Connectez-vous à votre compte
# 			</span>
# </h3>
# <form action="#" class="lql-form-content leo-login-form-content" method="post">
# <div class="form-group lql-form-mesg has-success">
# </div>
# <div class="form-group lql-form-mesg has-danger">
# </div>
# <div class="form-group lql-form-content-element">
# <input class="form-control lql-email-login" name="lql-email-login" placeholder="Adresse e-mail" required="" type="email"/>
# </div>
# <div class="form-group lql-form-content-element">
# <input class="form-control lql-pass-login" name="lql-pass-login" placeholder="Mot de passe" required="" type="password"/>
# </div>
# <div class="form-group row lql-form-content-element">
# <div class="col-xs-6">
# <input class="lql-rememberme" name="lql-rememberme" type="checkbox"/>
# <label class="form-control-label"><span>Se souvenir de moi</span></label>
# </div>
# <div class="col-xs-6 text-sm-right">
# <a class="leoquicklogin-forgotpass" href="#" role="button">Mot de passe oublié ?</a>
# </div>
# </div>
# <div class="form-group text-right">
# <button class="form-control-submit lql-form-bt lql-login-bt btn btn-primary" type="submit">
# <span class="leoquicklogin-loading leoquicklogin-cssload-speeding-wheel"></span>
# <i class="leoquicklogin-icon leoquicklogin-success-icon material-icons"></i>
# <i class="leoquicklogin-icon leoquicklogin-fail-icon material-icons"></i>
# <span class="lql-bt-txt">
# 						Connexion
# 					</span>
# </button>
# </div>
# <div class="form-group lql-callregister">
# <a class="lql-callregister-action" href="#" role="button">Pas de compte ? Créez-en un</a>
# </div>
# </form>
# <div class="leo-resetpass-form">
# <h3>Reset Password</h3>
# <form action="#" class="lql-form-content leo-resetpass-form-content" method="post">
# <div class="form-group lql-form-mesg has-success">
# </div>
# <div class="form-group lql-form-mesg has-danger">
# </div>
# <div class="form-group lql-form-content-element">
# <input class="form-control lql-email-reset" name="lql-email-reset" placeholder="Adresse e-mail" required="" type="email"/>
# </div>
# <div class="form-group">
# <button class="form-control-submit lql-form-bt leoquicklogin-reset-pass-bt btn btn-primary" type="submit">
# <span class="leoquicklogin-loading leoquicklogin-cssload-speeding-wheel"></span>
# <i class="leoquicklogin-icon leoquicklogin-success-icon material-icons"></i>
# <i class="leoquicklogin-icon leoquicklogin-fail-icon material-icons"></i>
# <span class="lql-bt-txt">
# 							Reset Password
# 						</span>
# </button>
# </div>
# </form>
# </div>
# </div>
# <div class="leo-form leo-register-form col-sm-6 leo-form-active">
# <h3 class="leo-register-title">
# 			Nouvelle inscription
# 		</h3>
# <form action="#" class="lql-form-content leo-register-form-content" method="post">
# <div class="form-group lql-form-mesg has-success">
# </div>
# <div class="form-group lql-form-mesg has-danger">
# </div>
# <div class="form-group lql-form-content-element">
# <input class="form-control lql-register-firstname" name="lql-register-firstname" placeholder="Prénom" type="text"/>
# </div>
# <div class="form-group lql-form-content-element">
# <input class="form-control lql-register-lastname" name="lql-register-lastname" placeholder="Nom" required="" type="text"/>
# </div>
# <div class="form-group lql-form-content-element">
# <input class="form-control lql-register-email" name="lql-register-email" placeholder="Adresse e-mail" required="" type="email"/>
# </div>
# <div class="form-group lql-form-content-element">
# <input class="form-control lql-register-pass" name="lql-register-pass" placeholder="Mot de passe" required="" type="password"/>
# </div>
# <label>
# <div class="form-group lql-form-content-element leo-form-chk">
# <input class="lql-register-check" name="lql-register-check" type="checkbox"/> J'accepte les conditions.
# 			</div>
# </label>
# <div class="form-group text-right">
# <button class="form-control-submit lql-form-bt lql-register-bt btn btn-primary" name="submit" type="submit">
# <span class="leoquicklogin-loading leoquicklogin-cssload-speeding-wheel"></span>
# <i class="leoquicklogin-icon leoquicklogin-success-icon material-icons"></i>
# <i class="leoquicklogin-icon leoquicklogin-fail-icon material-icons"></i>
# <span class="lql-bt-txt">
# 						Créez votre compte
# 					</span>
# </button>
# </div>
# <div class="form-group lql-calllogin">
# <div>Vous avez déjà un compte ?</div>
# <a class="lql-calllogin-action" href="#" role="button">Connectez-vous</a>
# 				Ou
# 				<a class="lql-calllogin-action lql-callreset-action" href="#" role="button">Réinitialiser le mot de passe</a>
# </div>
# </form>
# </div>
# </div>
# <div class="lql-social-login clearfix show-bt-txt">
# <h3 class="lql-social-login-title">
# 		Se connecter avec les réseaux sociaux
# 	</h3>
# <!--
# 		<div class="fb-login-button" data-max-rows="1" data-size="large" data-button-type="login_with" data-show-faces="false" data-auto-logout-link="false" data-use-continue-as="false" scope="public_profile,email" onlogin="checkLoginState();"></div>
# 		-->
# <button class="btn social-login-bt facebook-login-bt" onclick="doFbLogin();"><span class="fa fa-facebook"></span>Connectez-vous avec Facebook</button>
# <!--
# 		<div class="g-signin2" data-scope="profile email" data-longtitle="true" data-theme="dark" data-onsuccess="googleSignIn" data-onfailure="googleFail"></div>
# 	-->
# <button class="btn social-login-bt google-login-bt"><span class="fa fa-google"></span>Connectez-vous avec Google</button>
# <button class="btn social-login-bt twitter-login-bt"><span class="fa fa-twitter"></span>Connectez-vous avec Twitter</button>
# </div>
# </div>
# <div class="modal-footer"></div>
# </div>
# </div>
# </div><div class="leoquicklogin-mask"></div>
# <div class="leoquicklogin-slidebar">
# <div class="leoquicklogin-slidebar-wrapper">
# <div class="leoquicklogin-slidebar-top">
# <button class="leoquicklogin-slidebar-close btn btn-secondary" type="button">
# <i class="material-icons"></i>
# <span>Fermer</span>
# </button>
# </div>
# <div class="leo-quicklogin-form row">
# <div class="leo-form leo-login-form col-sm-6 leo-form-active">
# <h3 class="leo-login-title">
# <span class="title-both">
# 				Compté déjà existant
# 			</span>
# <span class="title-only">
# 				Connectez-vous à votre compte
# 			</span>
# </h3>
# <form action="#" class="lql-form-content leo-login-form-content" method="post">
# <div class="form-group lql-form-mesg has-success">
# </div>
# <div class="form-group lql-form-mesg has-danger">
# </div>
# <div class="form-group lql-form-content-element">
# <input class="form-control lql-email-login" name="lql-email-login" placeholder="Adresse e-mail" required="" type="email"/>
# </div>
# <div class="form-group lql-form-content-element">
# <input class="form-control lql-pass-login" name="lql-pass-login" placeholder="Mot de passe" required="" type="password"/>
# </div>
# <div class="form-group row lql-form-content-element">
# <div class="col-xs-6">
# <input class="lql-rememberme" name="lql-rememberme" type="checkbox"/>
# <label class="form-control-label"><span>Se souvenir de moi</span></label>
# </div>
# <div class="col-xs-6 text-sm-right">
# <a class="leoquicklogin-forgotpass" href="#" role="button">Mot de passe oublié ?</a>
# </div>
# </div>
# <div class="form-group text-right">
# <button class="form-control-submit lql-form-bt lql-login-bt btn btn-primary" type="submit">
# <span class="leoquicklogin-loading leoquicklogin-cssload-speeding-wheel"></span>
# <i class="leoquicklogin-icon leoquicklogin-success-icon material-icons"></i>
# <i class="leoquicklogin-icon leoquicklogin-fail-icon material-icons"></i>
# <span class="lql-bt-txt">
# 						Connexion
# 					</span>
# </button>
# </div>
# <div class="form-group lql-callregister">
# <a class="lql-callregister-action" href="#" role="button">Pas de compte ? Créez-en un</a>
# </div>
# </form>
# <div class="leo-resetpass-form">
# <h3>Reset Password</h3>
# <form action="#" class="lql-form-content leo-resetpass-form-content" method="post">
# <div class="form-group lql-form-mesg has-success">
# </div>
# <div class="form-group lql-form-mesg has-danger">
# </div>
# <div class="form-group lql-form-content-element">
# <input class="form-control lql-email-reset" name="lql-email-reset" placeholder="Adresse e-mail" required="" type="email"/>
# </div>
# <div class="form-group">
# <button class="form-control-submit lql-form-bt leoquicklogin-reset-pass-bt btn btn-primary" type="submit">
# <span class="leoquicklogin-loading leoquicklogin-cssload-speeding-wheel"></span>
# <i class="leoquicklogin-icon leoquicklogin-success-icon material-icons"></i>
# <i class="leoquicklogin-icon leoquicklogin-fail-icon material-icons"></i>
# <span class="lql-bt-txt">
# 							Reset Password
# 						</span>
# </button>
# </div>
# </form>
# </div>
# </div>
# <div class="leo-form leo-register-form col-sm-6 leo-form-active">
# <h3 class="leo-register-title">
# 			Nouvelle inscription
# 		</h3>
# <form action="#" class="lql-form-content leo-register-form-content" method="post">
# <div class="form-group lql-form-mesg has-success">
# </div>
# <div class="form-group lql-form-mesg has-danger">
# </div>
# <div class="form-group lql-form-content-element">
# <input class="form-control lql-register-firstname" name="lql-register-firstname" placeholder="Prénom" type="text"/>
# </div>
# <div class="form-group lql-form-content-element">
# <input class="form-control lql-register-lastname" name="lql-register-lastname" placeholder="Nom" required="" type="text"/>
# </div>
# <div class="form-group lql-form-content-element">
# <input class="form-control lql-register-email" name="lql-register-email" placeholder="Adresse e-mail" required="" type="email"/>
# </div>
# <div class="form-group lql-form-content-element">
# <input class="form-control lql-register-pass" name="lql-register-pass" placeholder="Mot de passe" required="" type="password"/>
# </div>
# <label>
# <div class="form-group lql-form-content-element leo-form-chk">
# <input class="lql-register-check" name="lql-register-check" type="checkbox"/> J'accepte les conditions.
# 			</div>
# </label>
# <div class="form-group text-right">
# <button class="form-control-submit lql-form-bt lql-register-bt btn btn-primary" name="submit" type="submit">
# <span class="leoquicklogin-loading leoquicklogin-cssload-speeding-wheel"></span>
# <i class="leoquicklogin-icon leoquicklogin-success-icon material-icons"></i>
# <i class="leoquicklogin-icon leoquicklogin-fail-icon material-icons"></i>
# <span class="lql-bt-txt">
# 						Créez votre compte
# 					</span>
# </button>
# </div>
# <div class="form-group lql-calllogin">
# <div>Vous avez déjà un compte ?</div>
# <a class="lql-calllogin-action" href="#" role="button">Connectez-vous</a>
# 				Ou
# 				<a class="lql-calllogin-action lql-callreset-action" href="#" role="button">Réinitialiser le mot de passe</a>
# </div>
# </form>
# </div>
# </div>
# <div class="lql-social-login clearfix show-bt-txt">
# <h3 class="lql-social-login-title">
# 		Se connecter avec les réseaux sociaux
# 	</h3>
# <!--
# 		<div class="fb-login-button" data-max-rows="1" data-size="large" data-button-type="login_with" data-show-faces="false" data-auto-logout-link="false" data-use-continue-as="false" scope="public_profile,email" onlogin="checkLoginState();"></div>
# 		-->
# <button class="btn social-login-bt facebook-login-bt" onclick="doFbLogin();"><span class="fa fa-facebook"></span>Connectez-vous avec Facebook</button>
# <!--
# 		<div class="g-signin2" data-scope="profile email" data-longtitle="true" data-theme="dark" data-onsuccess="googleSignIn" data-onfailure="googleFail"></div>
# 	-->
# <button class="btn social-login-bt google-login-bt"><span class="fa fa-google"></span>Connectez-vous avec Google</button>
# <button class="btn social-login-bt twitter-login-bt"><span class="fa fa-twitter"></span>Connectez-vous avec Twitter</button>
# </div>
# <div class="leoquicklogin-slidebar-bottom">
# <button class="leoquicklogin-slidebar-close btn btn-secondary" type="button">
# <i class="material-icons"></i>
# <span>Fermer</span>
# </button>
# </div>
# </div>
# </div>
# <div aria-hidden="true" class="modal lql-social-modal fade" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# <h5 class="modal-title lql-social-modal-mesg lql-social-loading">
# <span class="leoquicklogin-cssload-speeding-wheel"></span>
# </h5>
# <h5 class="modal-title lql-social-modal-mesg error-email">
# <i class="material-icons"></i>
# 				Vous ne pouvez pas vous connecter sans courriel!
# 			</h5>
# <h5 class="modal-title lql-social-modal-mesg error-email">
# 				Vérifiez votre compte social et donnez la permission d'utiliser vos informations de courrier électronique
# 			</h5>
# <h5 class="modal-title lql-social-modal-mesg error-login">
# <i class="material-icons"></i>
# 				Vous ne pouvez pas vous connecter!
# 			</h5>
# <h5 class="modal-title lql-social-modal-mesg error-login">
# 				Contactez-nous ou essayez de vous connecter d'une autre manière
# 			</h5>
# <h5 class="modal-title lql-social-modal-mesg success">
# <i class="material-icons"></i>
# 				Réussi!
# 			</h5>
# <h5 class="modal-title lql-social-modal-mesg success">
# 				Merci de vous connecter
# 			</h5>
# </div>
# </div>
# </div>
# </div> <style>
#         .ets_cookie_banber_block{
#     width :250px;
#     border: 1px solid #9e9e9e;
#     background: #e2e2e2;
#     border-radius: 3px;
#     box-shadow: 0 0 7px -2px #9e9e9e;
# }
# .btn.ets-cb-btn-ok,
# .btn.ets-cb-btn-ok:focus:not(:hover),
# .btn.ets-cb-btn-ok:active:not(:hover){
#     background: #033a7d;
#     color: #ffffff;
#     border-color: #033a7d;
# }
# .btn.ets-cb-btn-ok:hover{
#     background: #2598a9;
#     color: #ffffff;
#     border-color: #2598a9;
# }
#     </style>
# <div class="ets_cookie_banber_block right_bottom">
# <span class="close_cookie"></span>
# <div class="ets_cookie_banner_content">
# <p><img alt="Cookies" height="100" src="https://www.tradergames.fr/img/cms/614131.png" style="margin-left:auto;margin-right:auto;" width="100"/></p>
# <p style="text-align:center;">Ce site enregistre de délicieux cookies pour vous fournir une meilleur expérience.</p>
# </div>
# <div class="ets_cookie_banner_footer">
# <a class="btn btn-primary ets-cb-btn-ok" href="https://www.tradergames.fr/fr/module/ets_cookie_banner/submit">Accepter</a>
# </div>
# </div>
# </body>
# </html>

# %% [markdown]
# ### Titre de la page

# %%
print(page.find("title"))
# Out:
# <title>Derniers arrivages</title>

# %% [markdown]
# ### Toutes les images présentes sur la page

# %%
"""
page.findAll("img")[0:5]
"""
# Out:
# [<img alt="fr" height="11" src="https://www.tradergames.fr/img/l/1.jpg" width="16"/>,
#  <img alt="en" height="11" src="https://www.tradergames.fr/img/l/2.jpg" width="16"/>,
#  <img alt="Trader Games" class="logo img-fluid" src="https://www.tradergames.fr/img/prestashop-logo-1620838179.jpg"/>,
#  <img src="/img/stickers/11/Royaume-Uni Rectangle.png" style="opacity: ;position: static;box-shadow:unset;width:40%"/>,
#  <img src="/img/stickers/24/Neuf.png" style="opacity: ;position: static;box-shadow:unset;width:50%"/>]

# %% [markdown]
# ### Construction du dataset

# %% [markdown]
# #### Pour construire notre dataset on va récupérer les données présentes pour chaque produit.
# ##### Parcours dans une boucle for : Liste des images des jeux du site

# %%
"""
for item in page.findAll("img", {'class' : 'img-fluid'})[0:5] :
    print(item, "\n--------")
"""
# Out:
# <img alt="Trader Games" class="logo img-fluid" src="https://www.tradergames.fr/img/prestashop-logo-1620838179.jpg"/>
# --------
# <img alt="" class="img-fluid" data-full-size-image-url="https://www.tradergames.fr/276035-large_default/yooka-laylee-ps4-uk-occasion-enfrdeesit.jpg" src="https://www.tradergames.fr/276035-home_default/yooka-laylee-ps4-uk-occasion-enfrdeesit.jpg"/>
# --------
# <img alt="" class="img-fluid" data-full-size-image-url="https://www.tradergames.fr/276021-large_default/les-sisters-show-devant-ps4-fr-occasion.jpg" src="https://www.tradergames.fr/276021-home_default/les-sisters-show-devant-ps4-fr-occasion.jpg"/>
# --------
# <img alt="" class="img-fluid" data-full-size-image-url="https://www.tradergames.fr/276015-large_default/assassin-s-creed-valhalla-ps5-de-occasion-enfrdeesitpt.jpg" src="https://www.tradergames.fr/276015-home_default/assassin-s-creed-valhalla-ps5-de-occasion-enfrdeesitpt.jpg"/>
# --------
# <img alt="" class="img-fluid" data-full-size-image-url="https://www.tradergames.fr/276008-large_default/tokyo-ghoul-re-call-to-exist-ps4-japan-occasion-jp.jpg" src="https://www.tradergames.fr/276008-home_default/tokyo-ghoul-re-call-to-exist-ps4-japan-occasion-jp.jpg"/>
# --------

# %% [markdown]
# #### On n'a pas envie de prendre le premier élément qui ne correspond pas à un jeu mais au logo du site. On remarque aussi que l'image de jeu a comme classe 'data-full-size-image-url'

# %%
"""
for e, item in enumerate(page.findAll("img", {'class' : 'img-fluid'})[0:5]) : 
    if  e == 0: 
        pass
    else : 
        print(item)
        
"""
# Out:
# <img alt="" class="img-fluid" data-full-size-image-url="https://www.tradergames.fr/276097-large_default/tactics-ogre-reborn-ps4-uk-new-enfrdees.jpg" src="https://www.tradergames.fr/276097-home_default/tactics-ogre-reborn-ps4-uk-new-enfrdees.jpg"/>
# <img alt="" class="img-fluid" data-full-size-image-url="https://www.tradergames.fr/276091-large_default/tactics-ogre-reborn-ps5-uk-new-enfrdees.jpg" src="https://www.tradergames.fr/276091-home_default/tactics-ogre-reborn-ps5-uk-new-enfrdees.jpg"/>
# <img alt="" class="img-fluid" data-full-size-image-url="https://www.tradergames.fr/276083-large_default/tactics-ogre-reborn-switch-uk-new-enfrdees.jpg" src="https://www.tradergames.fr/276083-home_default/tactics-ogre-reborn-switch-uk-new-enfrdees.jpg"/>
# <img alt="" class="img-fluid" data-full-size-image-url="https://www.tradergames.fr/276077-large_default/police-simulator-patrol-officers-ps5-uk-new-enfrdeesitpt.jpg" src="https://www.tradergames.fr/276077-home_default/police-simulator-patrol-officers-ps5-uk-new-enfrdeesitpt.jpg"/>

# %%
for item in page.findAll("img", {'class' : 'img-fluid'})[0:5] : 
    if item.get("data-full-size-image-url") :
        print(item)
# Out:
# <img alt="" class="img-fluid" data-full-size-image-url="https://www.tradergames.fr/276097-large_default/tactics-ogre-reborn-ps4-uk-new-enfrdees.jpg" src="https://www.tradergames.fr/276097-home_default/tactics-ogre-reborn-ps4-uk-new-enfrdees.jpg"/>
# <img alt="" class="img-fluid" data-full-size-image-url="https://www.tradergames.fr/276091-large_default/tactics-ogre-reborn-ps5-uk-new-enfrdees.jpg" src="https://www.tradergames.fr/276091-home_default/tactics-ogre-reborn-ps5-uk-new-enfrdees.jpg"/>
# <img alt="" class="img-fluid" data-full-size-image-url="https://www.tradergames.fr/276083-large_default/tactics-ogre-reborn-switch-uk-new-enfrdees.jpg" src="https://www.tradergames.fr/276083-home_default/tactics-ogre-reborn-switch-uk-new-enfrdees.jpg"/>
# <img alt="" class="img-fluid" data-full-size-image-url="https://www.tradergames.fr/276077-large_default/police-simulator-patrol-officers-ps5-uk-new-enfrdeesitpt.jpg" src="https://www.tradergames.fr/276077-home_default/police-simulator-patrol-officers-ps5-uk-new-enfrdeesitpt.jpg"/>

# %% [markdown]
# #### Enfin, on récupère les URLs des images.

# %%
for item in page.findAll("img", {'class' : 'img-fluid'})[0:5] : 
    if item.get("data-full-size-image-url") :
        print(item.get("data-full-size-image-url"))
# Out:
# https://www.tradergames.fr/276097-large_default/tactics-ogre-reborn-ps4-uk-new-enfrdees.jpg
# https://www.tradergames.fr/276091-large_default/tactics-ogre-reborn-ps5-uk-new-enfrdees.jpg
# https://www.tradergames.fr/276083-large_default/tactics-ogre-reborn-switch-uk-new-enfrdees.jpg
# https://www.tradergames.fr/276077-large_default/police-simulator-patrol-officers-ps5-uk-new-enfrdeesitpt.jpg

# %% [markdown]
# #### On récupère les noms des jeux.

# %%
for item in page.findAll('h3', {'class' : 'h3 product-title'})[0:5] : 
        print(item.getText())
# Out:
# YOOKA LAYLEE PS4 UK...
# LES SISTERS SHOW DEVANT PS4...
# ASSASSIN S CREED VALHALLA...
# TOKYO GHOUL RE CALL TO...
# TSUIHOU SENKYO PS4 JAPAN...

# %% [markdown]
# #### On récupère les prix.

# %%
for item in page.findAll('span', {'itemprop' : 'price'})[0:5] : 
        print(item.getText())
# Out:
# 14,99 €
# 24,99 €
# 24,99 €
# 19,99 €
# 29,99 €

# %% [markdown]
# #### On récupère leur provenance.

# %%
for item in page.findAll('img', {'src' : '/img/stickers/'})[0:5] : 
        print(item.get())

# %%
import pandas

liste_noms = []
liste_urls = []
liste_prices = []
        
for item in page.findAll('h3', {'class' : 'h3 product-title'})[0:29] : 
        liste_noms.append(item.getText())
        
for item in page.findAll("img", {'class' : 'img-fluid'})[0:30] : 
    if item.get("data-full-size-image-url") :
        liste_urls.append(item.get("data-full-size-image-url"))

for item in page.findAll('span', {'itemprop' : 'price'})[0:29] : 
        liste_prices.append(item.getText())
        
df = pandas.DataFrame.from_dict( {"nom_jeux" : liste_noms, 'urls' : liste_urls, 'prix' : liste_prices})

# %%
df.head()
# Out:
#                         nom_jeux  \
# 0  TACTICS OGRE REBORN PS4 UK...
# 1  TACTICS OGRE REBORN PS5 UK...
# 2  TACTICS OGRE REBORN SWITCH...
# 3     POLICE SIMULATOR PATROL...
# 4   SYBERIA 3 PS4 UK OCCASION...
#
#                                                 urls     prix
# 0  https://www.tradergames.fr/276097-large_defaul...  49,99 €
# 1  https://www.tradergames.fr/276091-large_defaul...  49,99 €
# 2  https://www.tradergames.fr/276083-large_defaul...  49,99 €
# 3  https://www.tradergames.fr/276077-large_defaul...  39,99 €
# 4  https://www.tradergames.fr/276063-large_defaul...  14,99 €

# %%
df
# Out:
#                           nom_jeux  \
# 0    TACTICS OGRE REBORN PS4 UK...
# 1    TACTICS OGRE REBORN PS5 UK...
# 2    TACTICS OGRE REBORN SWITCH...
# 3       POLICE SIMULATOR PATROL...
# 4     SYBERIA 3 PS4 UK OCCASION...
# 5    CHORUS - DAY ONE EDITION -...
# 6     DARK SOULS REMASTERED PS4...
# 7     LEGO DC SUPER VILAINS PS4...
# 8           YOOKA LAYLEE PS4 UK...
# 9        METAL GEAR SOLID V THE...
# 10  LES SISTERS SHOW DEVANT PS4...
# 11    ASSASSIN S CREED VALHALLA...
# 12       TOKYO GHOUL RE CALL TO...
# 13     TSUIHOU SENKYO PS4 JAPAN...
# 14    MARIO + RABBIDS SPARKS OF...
# 15     COBRA KAI 2 DOJOS RISING...
# 16     COBRA KAI 2 DOJOS RISING...
# 17     COBRA KAI 2 DOJOS RISING...
# 18  STAR OCEAN THE DIVINE FORCE...
# 19       THE DIOFIELD CHRONICLE...
# 20    NBA 2K23 - MICHAEL JORDAN...
# 21   MARIO + THE LAPINS CRETINS...
# 22   DRAGON BALL THE BREAKERS -...
# 23    DONKEY KONG CASQUE STEREO...
# 24      POKEMON CASQUE SANS FIL...
# 25  SUPER MARIO CASQUE SANS FIL...
# 26           SUPER MARIO CASQUE...
# 27  POKEMON PIKACHU CASQUE POUR...
# 28  ANIMAL CROSSING CASQUE POUR...
#
#                                                  urls     prix
# 0   https://www.tradergames.fr/276097-large_defaul...  49,99 €
# 1   https://www.tradergames.fr/276091-large_defaul...  49,99 €
# 2   https://www.tradergames.fr/276083-large_defaul...  49,99 €
# 3   https://www.tradergames.fr/276077-large_defaul...  39,99 €
# 4   https://www.tradergames.fr/276063-large_defaul...  14,99 €
# 5   https://www.tradergames.fr/276056-large_defaul...  24,99 €
# 6   https://www.tradergames.fr/276049-large_defaul...  19,99 €
# 7   https://www.tradergames.fr/276045-large_defaul...  14,99 €
# 8   https://www.tradergames.fr/276035-large_defaul...  14,99 €
# 9   https://www.tradergames.fr/276069-large_defaul...   8,99 €
# 10  https://www.tradergames.fr/276021-large_defaul...  24,99 €
# 11  https://www.tradergames.fr/276015-large_defaul...  24,99 €
# 12  https://www.tradergames.fr/276008-large_defaul...  19,99 €
# 13  https://www.tradergames.fr/276003-large_defaul...  29,99 €
# 14  https://www.tradergames.fr/276001-large_defaul...  49,99 €
# 15  https://www.tradergames.fr/275995-large_defaul...  49,99 €
# 16  https://www.tradergames.fr/275993-large_defaul...  49,99 €
# 17  https://www.tradergames.fr/275991-large_defaul...  49,99 €
# 18  https://www.tradergames.fr/275971-large_defaul...  44,99 €
# 19  https://www.tradergames.fr/275966-large_defaul...  49,99 €
# 20  https://www.tradergames.fr/275989-large_defaul...  89,99 €
# 21  https://www.tradergames.fr/275987-large_defaul...  89,99 €
# 22  https://www.tradergames.fr/275985-large_defaul...  29,99 €
# 23  https://www.tradergames.fr/275940-large_defaul...  19,99 €
# 24  https://www.tradergames.fr/275936-large_defaul...  39,99 €
# 25  https://www.tradergames.fr/275932-large_defaul...  39,99 €
# 26  https://www.tradergames.fr/275928-large_defaul...  29,99 €
# 27  https://www.tradergames.fr/275924-large_defaul...  19,99 €
# 28  https://www.tradergames.fr/275920-large_defaul...  19,99 €
